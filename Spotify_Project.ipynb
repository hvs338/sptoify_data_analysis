# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datacleaner as dc
import seaborn as sns
import os

# %% [markdown]
# NOTES
#
# Important

# %% [markdown]
# # Load Data

# %%
daily_charts = pd.read_csv("spotify_daily_charts.csv")
daily_charts_artists = pd.read_csv("spotify_daily_charts_artists.csv")
daily_charts_tracks = pd.read_csv("spotify_daily_charts_tracks.csv")
artist_tracks_data = pd.read_csv("artist_tracks_data.csv")

# %%
print(daily_charts.shape)
daily_charts.head(5)
# Out:
# (416000, 6)
#          date  position                track_id            track_name  \
# 0  2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1  2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2  2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# 3  2017-01-01         4  2rizacJSyD9S1IQUxUxnsK           All We Know
# 4  2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know
#
#              artist  streams
# 0        Bruno Mars   185236
# 1      James Arthur   180552
# 2  The Chainsmokers   158720
# 3  The Chainsmokers   130874
# 4          Maroon 5   129656

# %%
print(daily_charts_artists.shape)
daily_charts_artists.head(5)
# Out:
# (943, 5)
#                 artist_id       artist_name  total_followers  \
# 0  0du5cEVh5yTK9QJze8zA0C        Bruno Mars         43236735
# 1  4IWBUUAFIplrNtaOHcJPRM      James Arthur         10293374
# 2  69GGBxA162lTqCwzJG5jLp  The Chainsmokers         19465938
# 3  04gDigrS5kc9YWfZHwBETP          Maroon 5         37898474
# 4  5p7f24Rk5HkUZsaS3BLG5F  Hailee Steinfeld          8049727
#
#                                               genres  popularity
# 0                               ['dance pop', 'pop']          87
# 1                   ['pop', 'talent show', 'uk pop']          80
# 2  ['dance pop', 'edm', 'electropop', 'pop', 'pop...          80
# 3                                            ['pop']          85
# 4    ['dance pop', 'pop', 'post-teen pop', 'uk pop']          72

# %%
print(daily_charts_tracks.shape)
daily_charts_tracks.head(5)
# Out:
# (8932, 19)
#                  track_id            track_name               artist_id  \
# 0  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor  0du5cEVh5yTK9QJze8zA0C
# 1  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go  4IWBUUAFIplrNtaOHcJPRM
# 2  7BKLCZ1jbUBVqRi2FVlTVw                Closer  69GGBxA162lTqCwzJG5jLp
# 3  2rizacJSyD9S1IQUxUxnsK           All We Know  69GGBxA162lTqCwzJG5jLp
# 4  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know  04gDigrS5kc9YWfZHwBETP
#
#         artist_name                album_id  duration release_date  \
# 0        Bruno Mars  4PgleR09JVnm3zY1fW3XBA    261240   2016-11-17
# 1      James Arthur  7oiJYvEJHsmYtrgviAVIBD    211466   2016-10-28
# 2  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE    244960   2016-07-29
# 3  The Chainsmokers  0xmaV6EtJ4M3ebZUPRnhyb    194080   2016-09-29
# 4          Maroon 5  0fvTn3WXF39kQs9i3bnNpP    214480   2016-10-11
#
#    popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0          75         0.578   0.574   2.0    -6.209   1.0       0.0454
# 1          85         0.358   0.557  10.0    -7.398   1.0       0.0590
# 2          84         0.748   0.524   8.0    -5.599   1.0       0.0338
# 3          70         0.662   0.586   0.0    -8.821   1.0       0.0307
# 4           0         0.783   0.623   7.0    -6.126   1.0       0.0800
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.196           0.00000    0.0830    0.301  174.152
# 1         0.695           0.00000    0.0902    0.494   85.043
# 2         0.414           0.00000    0.1110    0.661   95.010
# 3         0.097           0.00272    0.1150    0.296   90.000
# 4         0.338           0.00000    0.0975    0.447  100.048

# %%
print(artist_tracks_data.shape)
artist_tracks_data.head(5)
# Out:
# (436, 17)
#             artist                album  track_number                      id  \
# 0  Angeline Quinto  @LoveAngelineQuinto             1  48pPpT5Xyli4tBCMiy4Zhs
# 1  Angeline Quinto  @LoveAngelineQuinto             2  12fSfbtn43L2KO6kqqW0rj
# 2  Angeline Quinto  @LoveAngelineQuinto             3  6B2UndFWylp4Y93FwADGVb
# 3  Angeline Quinto  @LoveAngelineQuinto             4  0Ba6MOshEq4QBV5qM4X0UZ
# 4  Angeline Quinto  @LoveAngelineQuinto             5  3Lc6STDL8CQfAY4t8QVZjT
#
#                      name                                   uri  duration_ms  \
# 0    Para Bang, Para Lang  spotify:track:48pPpT5Xyli4tBCMiy4Zhs       248711
# 1             'Di Na Tayo  spotify:track:12fSfbtn43L2KO6kqqW0rj       270132
# 2            At Ang Hirap  spotify:track:6B2UndFWylp4Y93FwADGVb       257567
# 3  Parang Tayo Pero Hindi  spotify:track:0Ba6MOshEq4QBV5qM4X0UZ       226377
# 4        Awit Ng Pag-ibig  spotify:track:3Lc6STDL8CQfAY4t8QVZjT       249939
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0         0.651         0.670   0.533          0.000000    0.1740    -5.851
# 1         0.292         0.710   0.657          0.000015    0.2360    -5.509
# 2         0.843         0.434   0.357          0.000002    0.1690    -8.532
# 3         0.711         0.527   0.413          0.000000    0.3270    -7.574
# 4         0.858         0.350   0.283          0.000002    0.0628    -8.120
#
#    speechiness    tempo  valence  popularity
# 0       0.0394   90.089    0.447          28
# 1       0.0470  139.965    0.425          28
# 2       0.0507  129.769    0.140          53
# 3       0.0320  127.282    0.236          19
# 4       0.0382  129.872    0.188          18

# %% [markdown]
# # Data Manipulation

# %%
# change to datetime objects for easier grouping
daily_charts.iloc[39406]
# Out:
# date                      2017-07-20
# position                           7
# track_id      3RXkboS74UYzN14xTqzPyY
# track_name                       NaN
# artist                           NaN
# streams                       121541
# Name: 39406, dtype: object

# %%
# Drop NA values from daily charts
daily_charts.dropna(inplace=True)
daily_charts.reset_index(drop=True, inplace=True)

# %%
# Drop NA values from daily charts of tracks
daily_charts_tracks.dropna(inplace=True)
daily_charts_tracks.reset_index(drop=True, inplace=True)

# %%
# No need to drop anything
daily_charts_artists.isna().sum().sum()
# Out:
# 0

# %%
#no need to drop anything
artist_tracks_data.isna().sum().sum()
# Out:
# 0

# %%
daily_charts["date"].str.split("-").to_numpy()
# Out:
# array([list(['2017', '01', '01']), list(['2017', '01', '01']),
#        list(['2017', '01', '01']), ..., list(['2022', '09', '15']),
#        list(['2022', '09', '15']), list(['2022', '09', '15'])],
#       dtype=object)

# %%
year = []
month = []
day = []
daily_charts_date = daily_charts["date"].str.split("-").to_numpy()
dist = daily_charts["date"].shape[0]
for x in range(dist):
    year.append(int(daily_charts_date[x][0]))
    month.append(int(daily_charts_date[x][1]))
    day.append(int(daily_charts_date[x][2]))

daily_charts["year"] = year
daily_charts["month"] = month
daily_charts["day"] = day

# %% [markdown]
# # Daily Charts EDA

# %%
daily_charts.describe()
# Out:
#             position        streams           year          month  \
# count  415990.000000  415990.000000  415990.000000  415990.000000
# mean      100.501298   55477.933400    2019.374576       6.310080
# std        57.734192   45515.459562       1.650338       3.393829
# min         1.000000   11004.000000    2017.000000       1.000000
# 25%        51.000000   28169.000000    2018.000000       3.000000
# 50%       101.000000   38302.000000    2019.000000       6.000000
# 75%       151.000000   64969.000000    2021.000000       9.000000
# max       200.000000  782316.000000    2022.000000      12.000000
#
#                  day
# count  415990.000000
# mean       15.657086
# std         8.787541
# min         1.000000
# 25%         8.000000
# 50%        16.000000
# 75%        23.000000
# max        31.000000

# %%
np.unique(daily_charts["year"])
# Out:
# array([2017, 2018, 2019, 2020, 2021, 2022], dtype=int64)

# %%
daily_charts_2017 = daily_charts[daily_charts["year"] == 2017]
daily_charts_2018 = daily_charts[daily_charts["year"] == 2018]
daily_charts_2019 = daily_charts[daily_charts["year"] == 2019]
daily_charts_2020 = daily_charts[daily_charts["year"] == 2020]
daily_charts_2021 = daily_charts[daily_charts["year"] == 2021]
daily_charts_2022 = daily_charts[daily_charts["year"] == 2022]

# %% [markdown]
# #### 2017

# %%
daily_charts_2017 = daily_charts_2017.drop_duplicates("track_name")

# %%
top_5_2017 = daily_charts_2017.sort_values(by = "streams",ascending = False).head(5)
top_5_2017
# Out:
#              date  position                track_id  \
# 49590  2017-09-09         1  7oAraczbemGSNWqnbkU87R
# 49390  2017-09-08         1  0mel2N9Ws9r4yLQn5QE21Y
# 46590  2017-08-25         1  2VjtYe7gpfUi2OkGxR2O2z
# 1002   2017-01-06         3  7qiZfU4dY1lWllzX7mPBI3
# 0      2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP
#
#                         track_name        artist  streams  year  month  day
# 49590         Too Good At Goodbyes     Sam Smith   304751  2017      9    9
# 49390  Too Good At Goodbyes - Edit     Sam Smith   248525  2017      9    8
# 46590     Look What You Made Me Do  Taylor Swift   224825  2017      8   25
# 1002                  Shape of You    Ed Sheeran   199901  2017      1    6
# 0             Versace on the Floor    Bruno Mars   185236  2017      1    1

# %%
sns.barplot(data=top_5_2017,x = "track_name",y = "streams")
plt.xticks(rotation= 90)
plt.title("Top 5 streamed songs of 2017")
plt.show()

# %% [markdown]
# ####  2018

# %%
daily_charts_2018 = daily_charts_2018.drop_duplicates("track_name")
top_5_2018 = daily_charts_2018.sort_values(by = "streams",ascending = False).head(5)
top_5_2018
# Out:
#               date  position                track_id  \
# 133796  2018-11-04         7  2rPE9A1vEgShuZxxzR2tZH
# 72390   2018-01-01         1  0ofbQMrRDsUaVKq2mGLEAb
# 72391   2018-01-01         2  0tgVpDi06FyKpA1z0VMD4v
# 72392   2018-01-01         3  3hBBKuWJfxlIlnd9QFoC8k
# 72393   2018-01-01         4  1mXVgsBdtIVeCLJnSnmtdV
#
#                         track_name          artist  streams  year  month  day
# 133796               thank u, next   Ariana Grande   177405  2018     11    4
# 72390    Havana (feat. Young Thug)  Camila Cabello   155633  2018      1    1
# 72391                      Perfect      Ed Sheeran   134756  2018      1    1
# 72392   What Lovers Do (feat. SZA)        Maroon 5   130898  2018      1    1
# 72393         Too Good At Goodbyes       Sam Smith   130798  2018      1    1

# %%
sns.barplot(data=top_5_2018,x = "track_name",y = "streams")
plt.xticks(rotation= 90)
plt.title("Top 5 streamed songs of 2018")
plt.show()

# %% [markdown]
# ####  2019

# %%
daily_charts_2019 = daily_charts_2019.drop_duplicates("track_name")
top_5_2019 = daily_charts_2019.sort_values(by = "streams",ascending = False).head(5)
sns.barplot(data=top_5_2019,x = "track_name",y = "streams")
plt.xticks(rotation= 90)
plt.title("Top 5 streamed songs of 2019")
plt.show()

# %% [markdown]
# #### 2020

# %%
daily_charts_2020 = daily_charts_2020.drop_duplicates("track_name")
top_5_2020 = daily_charts_2020.sort_values(by = "streams",ascending = False).head(5)
sns.barplot(data=top_5_2020,x = "track_name",y = "streams")
plt.xticks(rotation= 90)
plt.title("Top 5 streamed songs of 2020")
plt.show()

# %% [markdown]
# ### 2021

# %%
daily_charts_2021 = daily_charts_2021.drop_duplicates("track_name")
top_5_2021 = daily_charts_2021.sort_values(by = "streams",ascending = False).head(5)
sns.barplot(data=top_5_2021,x = "track_name",y = "streams")
plt.xticks(rotation= 90)
plt.title("Top 5 streamed songs of 2021")
plt.show()

# %%
top_5_2021
# Out:
#               date  position                track_id  \
# 319590  2021-05-21         1  3VqeTFIvhxu3DIe4eZVzGq
# 348790  2021-10-15         1  0gplL1WMoJ6iYaPgMCL0gX
# 329190  2021-07-09         1  0LThjFY2iTtNdd4wviwVV2
# 354390  2021-11-12         1  5enxwA8aAbwZbf5qCHORXi
# 344590  2021-09-24         1  3FeVmId7tL5YN8B7R3imoM
#
#                                                track_name        artist  \
# 319590                                             Butter           BTS
# 348790                                         Easy On Me         Adele
# 329190                                Permission to Dance           BTS
# 354390  All Too Well (10 Minute Version) (Taylor's Ver...  Taylor Swift
# 344590                                        My Universe      Coldplay
#
#         streams  year  month  day
# 319590   753286  2021      5   21
# 348790   641241  2021     10   15
# 329190   590130  2021      7    9
# 354390   568476  2021     11   12
# 344590   523282  2021      9   24

# %% [markdown]
# #### 2022 : Up to 9/15/2022

# %%
daily_charts_2022 = daily_charts_2022.drop_duplicates("track_name")
top_5_2022 = daily_charts_2022.sort_values(by = "streams",ascending = False).head(5)
sns.barplot(data=top_5_2022,x = "track_name",y = "streams")
plt.xticks(rotation= 90)
plt.title("Top 5 streamed songs of 2022")
plt.show()

# %%
top_5_2022
# Out:
#               date  position                track_id  \
# 410390  2022-08-19         1  0skYUMpS0AcbpjcGsAbRGj
# 399190  2022-06-24         1  0mBP9X2gPCuapvpZ7TGDk3
# 396390  2022-06-10         1  10SRMwb9EuVS1K9rYsBfHQ
# 389391  2022-05-06         2  4d1CG5ei1E2vGbvmgf5KKv
# 396392  2022-06-10         3  69xohKu8C1fsflYAiSNbwM
#
#                                      track_name        artist  streams  year  \
# 410390                               Pink Venom     BLACKPINK   782316  2022
# 399190  Left and Right (Feat. Jung Kook of BTS)  Charlie Puth   553826  2022
# 396390                              Yet To Come           BTS   427273  2022
# 389391             This Love (Taylor’s Version)  Taylor Swift   332630  2022
# 396392                                  Run BTS           BTS   316056  2022
#
#         month  day
# 410390      8   19
# 399190      6   24
# 396390      6   10
# 389391      5    6
# 396392      6   10

# %% [markdown]
# #### Most Streamed Artisits from 2017-2022

# %%
top_ten_artisits = daily_charts.groupby(by = "artist")["streams"].sum().sort_values(ascending = False).head(20).to_frame()
top_ten_artisits
# Out:
#                     streams
# artist
# Ben&Ben           913820324
# Taylor Swift      567121184
# Ed Sheeran        563277361
# December Avenue   514362119
# LANY              495949117
# Moira Dela Torre  470145590
# BTS               437258393
# Ariana Grande     406589773
# Zack Tabudlo      370307235
# Olivia Rodrigo    339587420
# Lauv              339325876
# Maroon 5          321100384
# Justin Bieber     315152000
# Bruno Mars        307258243
# Arthur Nery       305623314
# BLACKPINK         303718588
# Post Malone       289254621
# Dua Lipa          274359779
# The Chainsmokers  227418848
# Silent Sanctuary  198435876

# %% [markdown]
# # Data Manipulation for ML

# %%
daily_charts_tracks["track_id"] = daily_charts_tracks["track_id"].astype(str)

# %%
daily_charts["track_id"] = daily_charts["track_id"].astype(str)

# %%
daily_charts_tracks = daily_charts_tracks.set_index("track_id")

daily_charts = daily_charts.set_index("track_id")

# %%
test = daily_charts_tracks.merge(daily_charts, on = "track_name",how = "left")

# %%
groupped_and_summed = test.groupby(by = ["track_name",'artist_id', 'artist_name', 'album_id', 'duration',
       'release_date', 'popularity', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo'], as_index= False)["streams"].sum()

# %%
groupped_and_summed.head(5)
# Out:
#        track_name               artist_id    artist_name  \
# 0       'Di Lahat  1dpv0XBdgUa5z4vzn7ahIz       Donnalyn
# 1  'Di Na Babalik  5HIZU0JzM0AgfItVOm4E08      This Band
# 2  'Di Na Babalik  5HIZU0JzM0AgfItVOm4E08      This Band
# 3     'Di Na Muli  09Xydf4dlkr29dH99DmsvQ  Janine Teñoso
# 4     'Di Na Muli  09Xydf4dlkr29dH99DmsvQ  Janine Teñoso
#
#                  album_id  duration release_date  popularity  danceability  \
# 0  3QxcPmbxKj6qFK3NqDexA7    234893   2018-10-05           0         0.686
# 1  0pFRzLxgSt9QlXKuukR8A4    340262   2019-02-03           3         0.358
# 2  7zJxOlHuAGpCC7ZtKHm0Rz    340262   2019-02-03           0         0.358
# 3  1hwjIPHrnNBFuxWBWRHmge    207018   2018-04-06           0         0.413
# 4  4u7nLwDVRz7z0mxweMbVZ6    207018   2018-04-06           2         0.413
#
#    energy   key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.731   6.0    -6.765   1.0       0.0428       0.28100          0.021900
# 1   0.435  10.0    -7.265   1.0       0.0349       0.00819          0.000936
# 2   0.435  10.0    -7.265   1.0       0.0349       0.00819          0.000936
# 3   0.561   1.0    -3.092   1.0       0.0517       0.19200          0.000000
# 4   0.561   1.0    -3.092   1.0       0.0517       0.19200          0.000000
#
#    liveness  valence   tempo      streams
# 0    0.0964    0.433  94.008    1842188.0
# 1    0.1120    0.140  76.132   61335104.0
# 2    0.1120    0.140  76.132   61335104.0
# 3    0.0914    0.352  88.690  102548262.0
# 4    0.0914    0.352  88.690  102548262.0

# %%
#groupped_and_summed["popularity"] = groupped_and_summed["popularity"] / 100

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x_features = groupped_and_summed[['duration',
      'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo',"streams"]]
y_feature = groupped_and_summed[["popularity"]]

# %%
scaler = MinMaxScaler()
x_features[['duration',
      'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo',"streams"]] = scaler.fit_transform(x_features)
y_feature = scaler.fit_transform(y_feature)
# Out:
# C:\Users\harsmith\AppData\Local\Temp\ipykernel_60636\714970234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_features[['duration',

# %%
x_features
# Out:
#       duration  danceability    energy       key  loudness  mode  speechiness  \
# 0     0.342819      0.635236  0.727085  0.545455  0.715865   1.0     0.022770
# 1     0.525946      0.228288  0.422245  0.909091  0.695394   1.0     0.013592
# 2     0.525946      0.228288  0.422245  0.909091  0.695394   1.0     0.013592
# 3     0.294373      0.296526  0.552008  0.090909  0.866244   1.0     0.033109
# 4     0.294373      0.296526  0.552008  0.090909  0.866244   1.0     0.033109
# ...        ...           ...       ...       ...       ...   ...          ...
# 4454  0.330714      0.419355  0.522142  0.545455  0.713572   1.0     0.003950
# 4455  0.281955      0.764268  0.852729  1.000000  0.805977   0.0     0.050302
# 4456  0.281955      0.764268  0.852729  1.000000  0.805977   0.0     0.050418
# 4457  0.286416      0.517370  0.816684  0.363636  0.848229   1.0     0.057853
# 4458  0.333750      0.816377  0.897013  0.545455  0.801515   1.0     0.243727
#
#       acousticness  instrumentalness  liveness   valence     tempo   streams
# 0         0.282695          0.022765  0.080236  0.423890  0.264172  0.005286
# 1         0.008238          0.000973  0.096947  0.114165  0.155537  0.175986
# 2         0.008238          0.000973  0.096947  0.114165  0.155537  0.175986
# 3         0.193158          0.000000  0.074879  0.338266  0.231854  0.294237
# 4         0.193158          0.000000  0.074879  0.338266  0.231854  0.294237
# ...            ...               ...       ...       ...       ...       ...
# 4454      0.126759          0.000000  0.087306  0.265328  0.187266  0.068020
# 4455      0.001165          0.000044  0.329405  0.719873  0.452501  0.025491
# 4456      0.001165          0.000044  0.329405  0.719873  0.452513  0.003993
# 4457      0.173037          0.000000  0.111944  0.572939  0.349853  0.000616
# 4458      0.159958          0.000049  0.241564  0.619450  0.780665  0.000146
#
# [4459 rows x 13 columns]

# %%
y_feature
# Out:
# array([[0.        ],
#        [0.03125   ],
#        [0.        ],
#        ...,
#        [0.        ],
#        [0.66666667],
#        [0.        ]])

# %% [markdown]
# # Correlation of Features

# %%
corr = x_features.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_3f037_row0_col0, #T_3f037_row1_col1, #T_3f037_row2_col2, #T_3f037_row3_col3, #T_3f037_row4_col4, #T_3f037_row5_col5, #T_3f037_row6_col6, #T_3f037_row7_col7, #T_3f037_row8_col8, #T_3f037_row9_col9, #T_3f037_row10_col10, #T_3f037_row11_col11, #T_3f037_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3f037_row0_col1, #T_3f037_row3_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_3f037_row0_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_3f037_row0_col3, #T_3f037_row1_col8, #T_3f037_row4_col3, #T_3f037_row5_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_3f037_row0_col4, #T_3f037_row7_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_3f037_row0_col5, #T_3f037_row2_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_3f037_row0_col6, #T_3f037_row0_col9, #T_3f037_row0_col10, #T_3f037_row1_col11, #T_3f037_row2_col5, #T_3f037_row2_col7, #T_3f037_row2_col12, #T_3f037_row4_col8, #T_3f037_row5_col3, #T_3f037_row7_col1, #T_3f037_row7_col2, #T_3f037_row7_col4, #T_3f037_row10_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3f037_row0_col7, #T_3f037_row4_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3f037_row0_col8, #T_3f037_row3_col11, #T_3f037_row6_col12 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_3f037_row0_col11, #T_3f037_row2_col3, #T_3f037_row8_col12, #T_3f037_row9_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_3f037_row0_col12, #T_3f037_row3_col10, #T_3f037_row11_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_3f037_row1_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3f037_row1_col2, #T_3f037_row1_col10 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_3f037_row1_col3, #T_3f037_row3_col8, #T_3f037_row4_col9, #T_3f037_row5_col1, #T_3f037_row10_col12 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_3f037_row1_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_3f037_row1_col5, #T_3f037_row7_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3f037_row1_col6, #T_3f037_row5_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_3f037_row1_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_3f037_row1_col9, #T_3f037_row4_col5, #T_3f037_row5_col6, #T_3f037_row7_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_3f037_row1_col12, #T_3f037_row8_col10, #T_3f037_row11_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_3f037_row2_col0, #T_3f037_row9_col12, #T_3f037_row11_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_3f037_row2_col1, #T_3f037_row4_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_3f037_row2_col4 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_3f037_row2_col8, #T_3f037_row6_col0, #T_3f037_row8_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_3f037_row2_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_3f037_row2_col10 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_3f037_row2_col11 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_3f037_row3_col0, #T_3f037_row9_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_3f037_row3_col1, #T_3f037_row11_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_3f037_row3_col2, #T_3f037_row11_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_3f037_row3_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_3f037_row3_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3f037_row3_col7 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_3f037_row3_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3f037_row3_col12 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3f037_row4_col0, #T_3f037_row8_col3, #T_3f037_row10_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_3f037_row4_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_3f037_row4_col6, #T_3f037_row4_col11, #T_3f037_row7_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_3f037_row4_col7, #T_3f037_row11_col9, #T_3f037_row12_col11 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3f037_row4_col12, #T_3f037_row8_col9, #T_3f037_row12_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_3f037_row5_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_3f037_row5_col4, #T_3f037_row10_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_3f037_row5_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_3f037_row5_col8, #T_3f037_row10_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_3f037_row5_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_3f037_row5_col10, #T_3f037_row6_col9, #T_3f037_row9_col5, #T_3f037_row9_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_3f037_row5_col12, #T_3f037_row9_col10 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_3f037_row6_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_3f037_row6_col2, #T_3f037_row9_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_3f037_row6_col3, #T_3f037_row10_col11, #T_3f037_row12_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_3f037_row6_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_3f037_row6_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3f037_row6_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_3f037_row6_col8, #T_3f037_row7_col3, #T_3f037_row11_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_3f037_row6_col10 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_3f037_row6_col11 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_3f037_row7_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_3f037_row7_col9, #T_3f037_row7_col10, #T_3f037_row12_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_3f037_row7_col12, #T_3f037_row12_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_3f037_row8_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_3f037_row8_col1, #T_3f037_row11_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_3f037_row8_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_3f037_row8_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_3f037_row8_col5, #T_3f037_row11_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_3f037_row8_col6, #T_3f037_row9_col11, #T_3f037_row11_col12 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_3f037_row8_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_3f037_row9_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_3f037_row9_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_3f037_row9_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_3f037_row9_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_3f037_row10_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_3f037_row10_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_3f037_row10_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_3f037_row10_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_3f037_row10_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_3f037_row10_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3f037_row11_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_3f037_row11_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_3f037_row12_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_3f037_row12_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_3f037_row12_col2, #T_3f037_row12_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_3f037_row12_col7 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_3f037_row12_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_3f037_row12_col10 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f037">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f037_level0_col0" class="col_heading level0 col0" >duration</th>
#       <th id="T_3f037_level0_col1" class="col_heading level0 col1" >danceability</th>
#       <th id="T_3f037_level0_col2" class="col_heading lev

# %% [markdown]
# # Split Test and Train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features.to_numpy(), y_feature, test_size = 0.2,random_state=42)

# %% [markdown]
# # Linear Regression

# %%
from sklearn import linear_model
import sklearn.metrics as sm

# %%
regression = linear_model.LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(x_test)

# %%
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))
# Out:
# Mean absolute error = 0.27
# Mean squared error = 0.1
# Median absolute error = 0.25
# Explain variance score = 0.0
# R2 score = 0.0

# %% [markdown]
# # Logisitic Regression

# %% [markdown]
# #### Changing the Y to from between 0 -1 to either 0 or 1 based on if it is > 0.5

# %%
logisitc_y_train =[]
logisitc_y_test = []
for x in y_train:
    if x < 0.5:
        logisitc_y_train.append(0)
    else:
        logisitc_y_train.append(1)
for z in y_test:
        if z < 0.5:
            logisitc_y_test.append(0)
        else:
            logisitc_y_test.append(1)

# %%
model = linear_model.LogisticRegression(solver="liblinear")
model.fit(x_train,logisitc_y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
model.intercept_
# Out:
# array([-0.59368575])

# %%
model.coef_
# Out:
# array([[-0.41527118, -0.09790715, -0.58137554, -0.08252234,  1.76973811,
#          0.0253329 ,  0.01543808,  0.30563809,  0.31247066, -0.15783373,
#          0.42340244,  0.33614061,  0.8089329 ]])

# %%
model.score(x_test,logisitc_y_test)
# Out:
# 0.6210762331838565

# %%
confusion_matrix(logisitc_y_test,model.predict(x_test))
# Out:
# array([[  2, 335],
#        [  3, 552]], dtype=int64)

# %%
print(classification_report(logisitc_y_test,model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.01      0.01       337
#            1       0.62      0.99      0.77       555
#
#     accuracy                           0.62       892
#    macro avg       0.51      0.50      0.39       892
# weighted avg       0.54      0.62      0.48       892

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.model_selection import cross_val_score

# %%
my_tree = tree.DecisionTreeRegressor()

# %%
my_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions = my_tree.predict(X=x_test)

# %%
my_tree.score(x_test,y_test)
# Out:
# -0.8524957787012031

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import BaggingRegressor

# %%
RandomForest = BaggingRegressor()

# %%
RandomForest.fit(x_train,y_train)
# Out:
# C:\Users\harsmith\Anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:429: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# BaggingRegressor()

# %%
y_pred_rf = RandomForest.predict(x_test)

# %%
RandomForest.score(x_test,y_test)
# Out:
# -0.13724854201708991

# %% [markdown]
# # Neural Network: Sequential

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.losses import MeanSquaredError
import tensorflow as tf

# %%
model = Sequential()
#model.add(Dense(, input_shape=(13,), activation = "relu"))
model.add(Dense(50, activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(20,activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(8,activation = "sigmoid"))
model.add(Dense(1, activation='sigmoid'))

# %%
mse = MeanSquaredError()
opt = tf.keras.optimizers.Adam(learning_rate=1e-2)
model.compile(loss=mse, optimizer=opt , metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=20,verbose = 0)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                700
#
#  dense_1 (Dense)             (None, 20)                1020
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_2 (Dense)             (None, 8)                 168
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,897
# Trainable params: 1,897
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # XGBOOST: BEST MODEL

# %%
import xgboost as xg
from sklearn.metrics import mean_squared_error as MSE

# %%
xbg_r = xg.XGBRegressor(objective = "reg:squarederror",n_estimators = 10)

# %%
history = xbg_r.fit(x_train,y_train)

# %%
pred = xbg_r.predict(x_test)
 
# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
print("MSE:", round(MSE(y_test,pred),5))
# Out:
# RMSE :  0.309263
# MSE: 0.09564

# %% [markdown]
# # Data Manipulation

# %%
groupped_and_summed.sort_values("popularity",ascending = False)
# Out:
#                     track_name               artist_id     artist_name  \
# 1582           I Ain't Worried  5Pwc4xIPtQLFEnJriah9YJ     OneRepublic
# 261                  As It Was  6KImCVD70vtIoJWnq6nGn3    Harry Styles
# 1690           I'm Good (Blue)  1Cs0zKBU1kc0i8ypK3B9ai    David Guetta
# 1299             Glimpse of Us  3MZsBdqDrRTJihTHQrO6Dq            Joji
# 3844       Under The Influence  7bXgB6jMjp9ATFy66eO08Z     Chris Brown
# ...                        ...                     ...             ...
# 2505          Nandyan Agad Ako  2iB7AJhJmkWkkehY9ccB0j    Ex Battalion
# 2490                    NO ONE  7cVZApDoQZpS447nHTsNqu           LeeHi
# 2473                   My Time  3Nrfpe0tUJi4K4DXYWgMUX             BTS
# 2466  My Only Wish (This Year)  26dSoYclwsYLMAKD3tpOr4  Britney Spears
# 4458             항상 (HANGSANG)  0b1sIQumIAsNbqAoIClSpy          j-hope
#
#                     album_id  duration release_date  popularity  danceability  \
# 1582  04PEOM6kIEeq9lRp1asNP2    148485   2022-05-13          96         0.704
# 261   2pqdSWeJVsXAhHFuVLzuA8    167303   2022-03-31          96         0.520
# 1690  7M842DMhYVALrXsw3ty7B3    175238   2022-08-26          96         0.561
# 1299  6ZZvx0aefZV3LKa053fn71    233456   2022-06-10          95         0.440
# 3844  3okhA6w5uau6ZNhnVpwVww    184613   2019-10-04          95         0.733
# ...                      ...       ...          ...         ...           ...
# 2505  6Y8OKCmGEqn2JjbTEwIbdf    240178   2018-08-06           0         0.799
# 2490  47gO1PsZBE4DdS9ipfiHti    194596   2019-05-30           0         0.745
# 2473  7HXqq0fokRpOKG0bQW4xnB    234457   2020-02-21           0         0.674
# 2466  1hQ9IQJHI5F4LxzdCyR38r    257026   2019-11-13           0         0.666
# 4458  1bJ8O4jIyqSdunqT9RWXc9    229675   2018-03-02           0         0.832
#
#       energy   key  loudness  mode  speechiness  acousticness  \
# 1582   0.797   0.0    -5.927   1.0       0.0475       0.08260
# 261    0.731   6.0    -5.338   0.0       0.0557       0.34200
# 1690   0.965   7.0    -3.673   0.0       0.0343       0.00383
# 1299   0.317   8.0    -9.258   1.0       0.0531       0.89100
# 3844   0.690   9.0    -5.529   0.0       0.0427       0.06350
# ...      ...   ...       ...   ...          ...           ...
# 2505   0.529   9.0    -9.170   1.0       0.0615       0.66100
# 2490   0.613  11.0    -5.368   0.0       0.0427       0.22600
# 2473   0.640   0.0    -5.139   0.0       0.0339       0.15100
# 2466   0.824   0.0    -4.743   1.0       0.0267       0.17500
# 4458   0.896   6.0    -4.673   1.0       0.2330       0.15900
#
#       instrumentalness  liveness  valence    tempo     streams
# 1582          0.000745    0.0546    0.825  139.994   8972300.0
# 261           0.001010    0.3110    0.662  173.930  62416012.0
# 1690          0.000007    0.3710    0.304  128.040   1381376.0
# 1299          0.000005    0.1410    0.268  169.914  57919078.0
# 3844          0.000001    0.1050    0.310  116.992  12880556.0
# ...                ...       ...      ...      ...         ...
# 2505          0.000000    0.0856    0.601  128.050  12142832.0
# 2490          0.000000    0.0664    0.542   91.997     51836.0
# 2473          0.000000    0.0925    0.664   99.908   1712944.0
# 2466          0.000000    0.2050    0.698  147.064    945442.0
# 4458          0.000048    0.2470    0.618  178.998     50946.0
#
# [4459 rows x 19 columns]

# %%
daily_charts_artists2 = daily_charts_artists[["genres","artist_name"]]

# %%
genres_and_data = daily_charts_artists2.merge(groupped_and_summed,on="artist_name",how = "inner").drop_duplicates()

# %%
genres_and_data["genres"] = genres_and_data["genres"].str.replace("[","",regex = False).str.replace("]","",regex = False)

# %%
genres_and_data.to_csv()
# Out:
# ',genres,artist_name,track_name,artist_id,album_id,duration,release_date,popularity,danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,streams\r\n0,"\'dance pop\', \'pop\'",Bruno Mars,24K Magic,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,225983,2016-11-17,79,0.818,0.803,1.0,-4.282,1.0,0.0797,0.034,0.0,0.153,0.632,106.97,39774918.0\r\n1,"\'dance pop\', \'pop\'",Bruno Mars,Calling All My Lovelies,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,250080,2016-11-17,61,0.662,0.705,1.0,-6.56,0.0,0.0399,0.0392,2.38e-06,0.105,0.865,159.996,1249252.0\r\n2,"\'dance pop\', \'pop\'",Bruno Mars,Chunky,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,186973,2016-11-17,69,0.571,0.539,5.0,-4.446,0.0,0.116,0.0208,0.0,0.125,0.727,202.103,5247658.0\r\n3,"\'dance pop\', \'pop\'",Bruno Mars,Finesse,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,191000,2016-11-17,69,0.741,0.798,5.0,-5.342,0.0,0.0718,0.00781,0.0,0.0232,0.939,104.953,379396.0\r\n4,"\'dance pop\', \'pop\'",Bruno Mars,Finesse - Remix; feat. Cardi B,0du5cEVh5yTK9QJze8zA0C,3mumK2ar9b4JPhVOZR0V2p,217288,2017-12-20,75,0.704,0.859,5.0,-4.877,0.0,0.0996,0.0185,0.0,0.0215,0.926,105.115,35512692.0\r\n5,"\'dance pop\', \'pop\'",Bruno Mars,It Will Rain,0du5cEVh5yTK9QJze8zA0C,73pAZrAw8W3Ey9hBJYOVLt,257847,2011-09-27,62,0.574,0.824,2.0,-6.885,1.0,0.0463,0.359,0.0,0.0816,0.434,149.981,6980792.0\r\n6,"\'dance pop\', \'pop\'",Bruno Mars,Just the Way You Are,0du5cEVh5yTK9QJze8zA0C,1uyf3l2d4XYwiEqAb7t7fX,220734,2010-10-05,82,0.635,0.841,5.0,-5.379,1.0,0.0422,0.0134,0.0,0.0622,0.424,109.021,112017334.0\r\n7,"\'dance pop\', \'pop\'",Bruno Mars,Leave The Door Open,0du5cEVh5yTK9QJze8zA0C,1YgekJJTEueWDaMr7BYqPk,242096,2021-11-11,84,0.586,0.616,5.0,-7.964,1.0,0.0324,0.182,0.0,0.0927,0.719,148.088,106814704.0\r\n8,"\'dance pop\', \'pop\'",Bruno Mars,Leave The Door Open,0du5cEVh5yTK9QJze8zA0C,2qLI9pIjubUQMlpdmid2sE,242096,2021-11-11,11,0.586,0.616,5.0,-7.964,1.0,0.0324,0.182,0.0,0.0927,0.719,148.088,106814704.0\r\n9,"\'dance pop\', \'pop\'",Bruno Mars,Leave The Door Open,0du5cEVh5yTK9QJze8zA0C,7dfPqXck6BB9wpThrVYBss,242096,2021-03-05,22,0.586,0.616,5.0,-7.964,1.0,0.0324,0.182,0.0,0.0927,0.719,148.088,106814704.0\r\n10,"\'dance pop\', \'pop\'",Bruno Mars,Perm,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,210053,2016-11-17,64,0.853,0.871,8.0,-3.715,1.0,0.0851,0.0145,6.84e-05,0.198,0.863,124.021,1322920.0\r\n11,"\'dance pop\', \'pop\'",Bruno Mars,Skate,0du5cEVh5yTK9QJze8zA0C,2qLI9pIjubUQMlpdmid2sE,203122,2021-11-11,4,0.708,0.598,5.0,-8.365,1.0,0.0291,0.037,0.0,0.17,0.698,112.027,4961966.0\r\n12,"\'dance pop\', \'pop\'",Bruno Mars,Skate,0du5cEVh5yTK9QJze8zA0C,4AsebSFI8STBGRcVUJ3Tmo,203122,2021-07-30,11,0.708,0.598,5.0,-8.365,1.0,0.0291,0.037,0.0,0.17,0.698,112.027,4961966.0\r\n13,"\'dance pop\', \'pop\'",Bruno Mars,Smokin Out The Window,0du5cEVh5yTK9QJze8zA0C,1YgekJJTEueWDaMr7BYqPk,197442,2021-11-11,79,0.627,0.618,2.0,-8.529,1.0,0.0437,0.0558,0.0,0.351,0.848,82.03,30674076.0\r\n14,"\'dance pop\', \'pop\'",Bruno Mars,Smokin Out The Window,0du5cEVh5yTK9QJze8zA0C,2qLI9pIjubUQMlpdmid2sE,197442,2021-11-11,12,0.627,0.618,2.0,-8.529,1.0,0.0437,0.0558,0.0,0.351,0.848,82.03,30674076.0\r\n15,"\'dance pop\', \'pop\'",Bruno Mars,Smokin Out The Window,0du5cEVh5yTK9QJze8zA0C,3BBsMXl00IfMxO7LCpYFU8,197442,2021-11-05,18,0.627,0.618,2.0,-8.529,1.0,0.0437,0.0558,0.0,0.351,0.848,82.03,30674076.0\r\n16,"\'dance pop\', \'pop\'",Bruno Mars,Straight up & Down,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,198186,2016-11-17,61,0.552,0.733,3.0,-6.898,0.0,0.0933,0.0209,0.0,0.0858,0.643,143.56,3262616.0\r\n17,"\'dance pop\', \'pop\'",Bruno Mars,Talking to the Moon,0du5cEVh5yTK9QJze8zA0C,1uyf3l2d4XYwiEqAb7t7fX,217866,2010-10-05,82,0.498,0.59,1.0,-4.721,0.0,0.032,0.511,0.0,0.107,0.0784,145.867,34496670.0\r\n18,"\'dance pop\', \'pop\'",Bruno Mars,That\'s What I Like,0du5cEVh5yTK9QJze8zA0C,4PgleR09JVnm3zY1fW3XBA,206693,2016-11-17,83,0.853,0.56,1.0,-4.961,1.0,0.0406,0.013,0.0,0.0944,0.86,134.066,11345 ...
